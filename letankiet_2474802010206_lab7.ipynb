# %% [markdown]
# Lê Tấn Kiệt
# MSSV:2474802010206

# %% [markdown]
# bài tập 1:

# %%
import nltk.corpus

print(dir(nltk.corpus))
# Out:
# ['_LazyModule__lazymodule_globals', '_LazyModule__lazymodule_import', '_LazyModule__lazymodule_init', '_LazyModule__lazymodule_loaded', '_LazyModule__lazymodule_locals', '_LazyModule__lazymodule_name', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__']

# %% [markdown]
# bài tập 2 :

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords

print(stopwords.fileids())
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# bài tập 3

# %%
from nltk.corpus import stopwords

english_sw = stopwords.words('english')
vietnamese_sw = stopwords.words('english')  # NLTK không có sẵn tiếng Việt

print("English stopwords:", english_sw[:20])
print("Số lượng:", len(english_sw))
# Out:
# English stopwords: ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been']
# Số lượng: 198

# %% [markdown]
# bài tập 4

# %%
import nltk

# Download các tài nguyên cần thiết
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Văn bản cần xử lý
text = "This is a simple example to remove stopwords from a sentence."

# Tách từ
words = word_tokenize(text)

# Lấy danh sách stopwords tiếng Anh
stop_words = set(stopwords.words('english'))

# Loại bỏ stopwords
filtered_words = [word for word in words if word.lower() not in stop_words]

# In kết quả
print("Văn bản gốc:")
print(text)

print("\nDanh sách từ sau khi tách:")
print(words)

print("\nSau khi loại bỏ stopwords:")
print(filtered_words)

print("\nGhép lại thành câu:")
print(" ".join(filtered_words))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Văn bản gốc:
# This is a simple example to remove stopwords from a sentence.
#
# Danh sách từ sau khi tách:
# ['This', 'is', 'a', 'simple', 'example', 'to', 'remove', 'stopwords', 'from', 'a', 'sentence', '.']
#
# Sau khi loại bỏ stopwords:
# ['simple', 'example', 'remove', 'stopwords', 'sentence', '.']
#
# Ghép lại thành câu:
# simple example remove stopwords sentence .
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# bài tập 5

# %%
words = ["this", "is", "a", "good", "movie"]

sw = set(stopwords.words('english'))
result = [word for word in words if word not in sw]

print(result)
# Out:
# ['good', 'movie']

# %% [markdown]
# bài tập 6

# %%
nltk.download('wordnet')

from nltk.corpus import wordnet

word = "computer"
synsets = wordnet.synsets(word)

for syn in synsets[:3]:
    print("Định nghĩa:", syn.definition())
    print("Ví dụ:", syn.examples())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Định nghĩa: a machine for performing calculations automatically
# Ví dụ: []
# Định nghĩa: an expert at calculation (or at operating calculating machines)
# Ví dụ: []

# %% [markdown]
# bài tập 7

# %%
from nltk.corpus import wordnet

word = "good"

synonyms = []
antonyms = []

for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

print("Từ đồng nghĩa:", set(synonyms))
print("Từ trái nghĩa:", set(antonyms))
# Out:
# Từ đồng nghĩa: {'salutary', 'secure', 'dear', 'thoroughly', 'well', 'right', 'trade_good', 'beneficial', 'in_effect', 'estimable', 'upright', 'undecomposed', 'commodity', 'just', 'honorable', 'ripe', 'expert', 'in_force', 'sound', 'practiced', 'safe', 'unspoilt', 'good', 'proficient', 'serious', 'goodness', 'effective', 'unspoiled', 'soundly', 'honest', 'adept', 'full', 'dependable', 'skilful', 'skillful', 'near', 'respectable'}
# Từ trái nghĩa: {'ill', 'bad', 'evilness', 'evil', 'badness'}

# %% [markdown]
# bài tập 8

# %%
import nltk

# Tải đầy đủ dữ liệu cần thiết
nltk.download('tagsets')
nltk.download('tagsets_json')

# 1. Xem tổng quan bộ tag
print("=== TỔNG QUAN BỘ TAG ===")
nltk.help.upenn_tagset()

# 2. Xem chi tiết tag NN
print("\n=== CHI TIẾT TAG NN ===")
nltk.help.upenn_tagset('NN')

# 3. Xem các tag bắt đầu bằng VB
print("\n=== CÁC TAG LIÊN QUAN ĐẾN VB ===")
nltk.help.upenn_tagset('VB.*')
# Out:
# === TỔNG QUAN BỘ TAG ===
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %% [markdown]
# bài tập 9

# %%
from nltk.corpus import wordnet

noun1 = wordnet.synset('dog.n.01')
noun2 = wordnet.synset('cat.n.01')

similarity = noun1.path_similarity(noun2)

print("Độ giống nhau:", similarity)
# Out:
# Độ giống nhau: 0.2

# %% [markdown]
# bài tập 10

# %%
verb1 = wordnet.synset('run.v.01')
verb2 = wordnet.synset('walk.v.01')

similarity = verb1.path_similarity(verb2)

print("Độ giống nhau:", similarity)
# Out:
# Độ giống nhau: 0.25

# %% [markdown]
# bài tập 11

# %%
nltk.download('names')

from nltk.corpus import names

male_names = names.words('male.txt')
female_names = names.words('female.txt')

print("Số lượng tên nam:", len(male_names))
print("10 tên nam đầu:", male_names[:10])

print("Số lượng tên nữ:", len(female_names))
print("10 tên nữ đầu:", female_names[:10])
# Out:
# Số lượng tên nam: 2943
# 10 tên nam đầu: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# Số lượng tên nữ: 5001
# 10 tên nữ đầu: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.

# %% [markdown]
# bài tập 12

# %%
import random
from nltk.corpus import names

male_names = [(name, 'male') for name in names.words('male.txt')]
female_names = [(name, 'female') for name in names.words('female.txt')]

labeled_names = male_names + female_names
random.shuffle(labeled_names)

print(labeled_names[:15])
# Out:
# [('Antonino', 'male'), ('Armando', 'male'), ('Tate', 'male'), ('Siegfried', 'male'), ('Nesta', 'female'), ('Michal', 'male'), ('Raine', 'female'), ('Sophie', 'female'), ('Bethanne', 'female'), ('Percy', 'male'), ('Finn', 'male'), ('Arlette', 'female'), ('Jess', 'female'), ('Jorrie', 'female'), ('Kevin', 'male')]
